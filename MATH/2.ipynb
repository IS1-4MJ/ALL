# %%
# ONE IPYNB HERE

# %%
# YOU CAN SEE BELOW THIS LINE (POSSIBILITY CODE)
from IPython import display
display.Image("https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Oryctolagus_cuniculus_Rcdo.jpg/1200px-Oryctolagus_cuniculus_Rcdo.jpg",
              width=500, height=500)
# YOU CAN SEE ABOVE THIS LINE

# %%
# YOU CAN SEE BELOW THIS LINE (POSSIBILITY CODE)
display.Image("https://raw.githubusercontent.com/IS1-4MJ/ALL/main/IMAGE/0.jpg",
              width=500, height=500)
# YOU CAN SEE ABOVE THIS LINE
